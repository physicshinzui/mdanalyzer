# %%
import pandas as pd
file_suffix = 'test'

# %% [markdown]
# # RMSD calculation

# %%
df_rmsd = pd.read_csv(f'rmsd_{file_suffix}.csv', index_col = 1)
df_rmsd.head(5)
# Out:
#             # frame      RMSD (A)
#  time (ps)
# 0.0             0.0  1.231188e-07
# 100.0           1.0  4.284468e-01
# 200.0           2.0  3.707494e-01
# 300.0           3.0  5.813336e-01
# 400.0           4.0  4.120930e-01

# %%
df_rmsd.iloc[0:,1].plot(label='Protein', legend=True)
# Out:
# <AxesSubplot:xlabel=' time (ps)'>

# %%
# RMSF calculation

# %%
df_rmsf = pd.read_csv(f'rmsf_{file_suffix}.csv', index_col = 0)
df_rmsf.head()
# Out:
#              RMSF
# residue
# GLY0     2.349355
# MET1     1.750748
# SER2     1.035834
# GLN3     0.817075
# SER4     1.007868

# %%
df_rmsf.plot(label = 'C alpha', legend = True)
# Out:
# /Users/siida/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='residue'>
